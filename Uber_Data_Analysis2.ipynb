# %% [markdown]
# # Rideshare Data Analysis
# -----------------------------------------------------------------
#
# - Defining the problem statement
#
#
# - Collecting the data
#     * Kaggle
#
#
# - Exploratory data analysis

# %% [markdown]
# ## 1. Defining the problem statement
# ____________________________________________________
#
# In this project, we study the data of Uber which is present in tabular format in which we use different libraries like numpy, pandas and matplotlib and different machine learning algorithms.
#
# We study different columns of the table and try to co-relate them with others and find a relation between those two.
#
# We try to find and analyze those key factors like date, month etc which helps Uber Company to enhance their business by focusing on those services and make required changes.

# %% [markdown]
# ## 2. Collecting the data
# ___________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

uber_dataset = pd.read_csv(r"./rideshare_kaggle.csv")

# %% [markdown]
# ## 3. Exploratory data analysis
# __________________________________________________
#
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
# It is a good practice to understand the data first and try to gather as many insights from it.
#
# EDA is all about making sense of data in hand.

# %%
uber_dataset.head()
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type  ... precipIntensityMax uvIndexTime  temperatureMin  \
# ...

# %% [markdown]
# Dimensions of the uber data

# %%
uber_dataset.shape
# Out:
# (693071, 57)

# %% [markdown]
# **Detailed information about the Columns or Features**

# %%
uber_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           693071 non-null  object
#  1   timestamp                    693071 non-null  float64
#  2   hour                         693071 non-null  int64
#  3   day                          693071 non-null  int64
#  4   month                        693071 non-null  int64
#  5   datetime                     693071 non-null  object
#  6   timezone                     693071 non-null  object
#  7   source                       693071 non-null  object
#  8   destination                  693071 non-null  object
#  9   cab_type                     693071 non-null  object
#  10  product_id                   693071 non-null  object
#  11  name                         693071 non-null  object
# ...

# %%
uber_dataset.describe()
# Out:
#           timestamp           hour            day          month  \
# count  6.930710e+05  693071.000000  693071.000000  693071.000000
# mean   1.544046e+09      11.619137      17.794365      11.586684
# std    6.891925e+05       6.948114       9.982286       0.492429
# min    1.543204e+09       0.000000       1.000000      11.000000
# 25%    1.543444e+09       6.000000      13.000000      11.000000
# 50%    1.543737e+09      12.000000      17.000000      12.000000
# 75%    1.544828e+09      18.000000      28.000000      12.000000
# max    1.545161e+09      23.000000      30.000000      12.000000
#
#                price       distance  surge_multiplier       latitude  \
# count  637976.000000  693071.000000     693071.000000  693071.000000
# mean       16.545125       2.189430          1.013870      42.338172
# std         9.324359       1.138937          0.091641       0.047840
# min         2.500000       0.020000          1.000000      42.214800
# ...

# %% [markdown]
# **Print unique source**

# %%
start = uber_dataset['source'].dropna()
unique_start = set(start)
print(unique_start)
# Out:
# {'Haymarket Square', 'Beacon Hill', 'Back Bay', 'Fenway', 'South Station', 'Northeastern University', 'Boston University', 'Theatre District', 'North Station', 'West End', 'Financial District', 'North End'}

# %% [markdown]
# **Print unique destinations**

# %%
stop_dest = uber_dataset['destination'].dropna()
unique_stop = set(stop_dest)
print(unique_stop)
# Out:
# {'Haymarket Square', 'Beacon Hill', 'South Station', 'Northeastern University', 'Back Bay', 'Boston University', 'Theatre District', 'North Station', 'North End', 'West End', 'Financial District', 'Fenway'}

# %% [markdown]
# **Uber Trips with starting point as Boston University**

# %%
uber_dataset[uber_dataset['source'] == 'Boston University']
# Out:
#                                           id     timestamp  hour  day  month  \
# 76      0617e9b6-45f9-4f45-aa2b-5d06da008088  1.543784e+09    20    2     12
# 77      37b99b0e-d2a9-4aa6-b145-54de1c8793eb  1.544879e+09    13   15     12
# 78      433900c1-12d0-4771-85ea-1e1f1a4a6d63  1.543479e+09     8   29     11
# 79      76ec209b-45a1-47e7-9eda-bc3a22402b8e  1.543361e+09    23   27     11
# 80      a841f68a-a00f-456a-a3f2-2a4f2f2917d6  1.545003e+09    23   16     12
# ...                                      ...           ...   ...  ...    ...
# 692951  8e502297-c664-479b-9291-b9dd3051241b  1.543854e+09    16    3     12
# 692952  c09c8685-f7ae-4cfc-b08c-25a8f521f7af  1.543854e+09    16    3     12
# 692953  c5157200-a520-4553-9f24-6c729b2f4405  1.545058e+09    14   17     12
# 692954  eb775050-373d-4492-83b3-41cc485db346  1.545058e+09    14   17     12
# 692955  fdad2cb3-1989-4153-8c3d-43bf78d01c3f  1.545058e+09    14   17     12
#
# ...

# %% [markdown]
# **Identifying Null values**

# %%
uber_dataset.isnull().sum()
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# ...

# %% [markdown]
# **Popular starting points of uber drivers**

# %%
start_point = uber_dataset["source"].dropna()
df1 = pd.DataFrame(start_point.value_counts())
df1.sort_values(['source'],ascending=False)
df1 = df1.reset_index()
df1.loc[0:2]
# Out:
#                source  count
# 0  Financial District  58857
# 1    Theatre District  57813
# 2            Back Bay  57792

# %% [markdown]
# **Popular Destinations for customers to visit**

# %%
dest_point = uber_dataset["destination"].dropna()
df2 = pd.DataFrame(dest_point.value_counts())
df2.sort_values(['destination'],ascending=False)
df2 = df2.reset_index()
df2.loc[0:2]
# Out:
#           destination  count
# 0  Financial District  58851
# 1    Theatre District  57798
# 2            Back Bay  57780

# %% [markdown]
# **Most frequent route taken by uber drivers**

# %%
df3 = uber_dataset.dropna()
df3 = pd.DataFrame(df3.groupby(['source','destination']).size())
df3 = df3.rename(columns = {0:'Count'})
df3 = df3.sort_values(['Count'],ascending=False)
df3 = df3.reset_index()
df3.loc[0]
# Out:
# source              South Station
# destination    Financial District
# Count                        9534
# Name: 0, dtype: object

# %% [markdown]
# **Bar graph showing the number of people who traveled on a day with respect to precipitation**

# %%
# Assuming your DataFrame is named 'data'
# Group by 'day' to get the total number of people who traveled on each day
total_travelers_per_day = uber_dataset.groupby('day').size()

# Group by 'day' and calculate the mean precipitation for each day
mean_precipitation_per_day = uber_dataset.groupby('day')['precipIntensity'].mean()

# Plotting
fig, ax1 = plt.subplots()

# Bar plot for total travelers
ax1.bar(total_travelers_per_day.index, total_travelers_per_day.values, color='b', alpha=0.7, label='Total Travelers')
ax1.set_xlabel('Day')
ax1.set_ylabel('Total Travelers', color='b')
ax1.tick_params('y', colors='b')

# Line plot for mean precipitation
ax2 = ax1.twinx()
ax2.plot(mean_precipitation_per_day.index, mean_precipitation_per_day.values, color='r', marker='o', label='Mean Precipitation')
ax2.set_ylabel('Mean Precipitation', color='r')
ax2.tick_params('y', colors='r')

plt.title('Number of Travelers vs. Mean Precipitation Intensity')
plt.legend()
plt.show()

# %% [markdown]
# **Number of people who traveled on each day with respect to temperature**

# %%
# Assuming your DataFrame is named 'data'
# Group by 'day' to get the total number of people who traveled on each day
total_travelers_per_day = uber_dataset.groupby('day').size()

# Group by 'day' and calculate the mean temperature for each day
mean_temperature_per_day = uber_dataset.groupby('day')['temperature'].mean()

# Plotting
fig, ax1 = plt.subplots()

# Bar plot for total travelers
ax1.bar(total_travelers_per_day.index, total_travelers_per_day.values, color='b', alpha=0.7, label='Total Travelers')
ax1.set_xlabel('Day')
ax1.set_ylabel('Total Travelers', color='b')
ax1.tick_params('y', colors='b')

# Line plot for mean temperature
ax2 = ax1.twinx()
ax2.plot(mean_temperature_per_day.index, mean_temperature_per_day.values, color='r', marker='o', label='Mean Temperature')
ax2.set_ylabel('Mean Temperature', color='r')
ax2.tick_params('y', colors='r')

plt.title('Number of Travelers vs. Mean Temperature')
plt.legend()
plt.show()

# %% [markdown]
# **Distribution of Travelers by Source**

# %%
# Assuming your DataFrame is named 'data'
# Group by 'source' to get the count of travelers for each source
travelers_per_source = uber_dataset['source'].value_counts()

# Plotting pie chart for the distribution of travelers from each source
plt.figure(figsize=(8, 6))
plt.pie(travelers_per_source, labels=travelers_per_source.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Travelers by Source')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Assuming your DataFrame is named 'data'
# Group by 'destination' to get the count of travelers for each destination
travelers_per_destination = uber_dataset['destination'].value_counts()

# Plotting pie chart for the distribution of travelers to each destination
plt.figure(figsize=(8, 6))
plt.pie(travelers_per_destination, labels=travelers_per_destination.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Travelers by Destination')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Calculate the count of each unique value in the 'name' column
name_counts = uber_dataset['name'].value_counts()

# Plotting pie chart for the distribution of 'name' column
plt.figure(figsize=(8, 6))
plt.pie(name_counts, labels=name_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Cab Types (Names)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Assuming your DataFrame is named 'uber_dataset'

# Filter out rows where price is not null
uber_dataset_filtered = uber_dataset.dropna(subset=['price'])

# Plotting violin plot for ride prices by cab type
plt.figure(figsize=(12, 8))
sns.violinplot(data=uber_dataset_filtered, x='name', y='price', palette='muted')
plt.title('Ride Price Analysis by Cab Type')
plt.xlabel('Cab Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_130938/607425367.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=uber_dataset_filtered, x='name', y='price', palette='muted')

# %%
# Filter out rows where surge multiplier is not null
uber_dataset_filtered = uber_dataset.dropna(subset=['surge_multiplier'])

# Plotting violin plot of surge multiplier with respect to day for each day
plt.figure(figsize=(12, 8))
sns.violinplot(data=uber_dataset_filtered, x='day', y='surge_multiplier', hue='month', palette='muted')
plt.title('Violin Plot of Surge Multiplier with Respect to Day for Each day')
plt.xlabel('Day')
plt.ylabel('Surge Multiplier')
plt.grid(True)
plt.legend(title='day')
plt.show()

# %%
# Assuming your DataFrame is named 'uber_dataset'

# Filter out rows where surge multiplier is not null
uber_dataset_filtered = uber_dataset.dropna(subset=['surge_multiplier'])

# Plotting scatterplot of surge multiplier with respect to day
plt.figure(figsize=(10, 6))
plt.scatter(uber_dataset_filtered['day'], uber_dataset_filtered['surge_multiplier'], color='blue', alpha=0.5)
plt.title('Scatterplot of Surge Multiplier with Respect to Day')
plt.xlabel('Day')
plt.ylabel('Surge Multiplier')
plt.grid(True)
plt.show()

# %%
# Calculate total number of ride requests for each hour of the day
demand_by_hour = uber_dataset['hour'].value_counts().sort_index()

# Visualize demand variation throughout the day
plt.figure(figsize=(10, 6))
demand_by_hour.plot(kind='line', marker='o', color='blue')
plt.title('Demand Variation by Time of Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Ride Requests')
plt.xticks(range(24))  # Set x-axis ticks to represent each hour of the day
plt.grid(True)
plt.show()

# %%
demand_by_temp = uber_dataset['temperature'].value_counts().sort_index()

# Visualize demand variation throughout the day
plt.figure(figsize=(30, 6))
demand_by_temp.plot(kind='line', marker='o', color='blue')
plt.title('Demand Variation by Temperature')
plt.xlabel('Temperature')
plt.ylabel('Number of Ride Requests')
plt.grid(True)
plt.show()

# %%
demand_by_temp = uber_dataset['precipProbability'].value_counts().sort_index()

# Visualize demand variation throughout the day
plt.figure(figsize=(15, 6))
demand_by_temp.plot(kind='line', marker='o', color='blue')
plt.title('Demand Variation by Precipitation Probability')
plt.xlabel('Temperature')
plt.ylabel('Number of Ride Requests')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Strip Plots

# %%
sns.stripplot(data=uber_dataset, x='price', y='name', hue='name')
# Out:
# <Axes: xlabel='price', ylabel='name'>

# %%
sns.stripplot(data=uber_dataset, x='price', y='icon', hue='icon', palette='Set1', legend=False)
# Out:
# <Axes: xlabel='price', ylabel='icon'>

# %%
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='source', hue='source')
# Out:
# <Axes: xlabel='surge_multiplier', ylabel='source'>

# %%
sns.stripplot(data=uber_dataset, x='surge_multiplier', y='hour', hue='hour', legend=False)
# Out:
# <Axes: xlabel='surge_multiplier', ylabel='hour'>

# %% [markdown]
# #### Bar plots

# %%
uber_dataset['month'].value_counts().plot(kind='bar', figsize=(10,5), color='blue')
# Out:
# <Axes: xlabel='month'>

# %%
uber_dataset['source'].value_counts().plot(kind='bar', figsize=(10,5), color='green')
# Out:
# <Axes: xlabel='source'>

# %%
uber_dataset['name'].value_counts().plot(kind='bar', figsize=(10,5), color='orange')
# Out:
# <Axes: xlabel='name'>

# %%
uber_dataset['icon'].value_counts().plot(kind='bar', figsize=(10,5), color='red')
# Out:
# <Axes: xlabel='icon'>

# %%
uber_dataset['uvIndex'].value_counts().plot(kind='bar', figsize=(10,5), color='brown')
# Out:
# <Axes: xlabel='uvIndex'>

# %%
uber_dataset['moonPhase'].value_counts().plot(kind='bar', figsize=(10,5), color='orange')
# Out:
# <Axes: xlabel='moonPhase'>

# %%
uber_dataset['precipProbability'].value_counts().plot(kind='bar', figsize=(10,5), color='blue')
# Out:
# <Axes: xlabel='precipProbability'>
